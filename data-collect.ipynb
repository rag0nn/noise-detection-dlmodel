# %%
import cv2
import numpy as np
import os
from glob import glob
from tqdm import tqdm

# %%
os.getcwd()
# Out:
# 'C:\\Users\\asus\\Desktop\\project'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'data-collect.ipynb', 'images', 'src', 'vid']

# %%
target_path = "./images/"
packs = os.listdir('src')
for i,pack in enumerate(packs):
    sub_path = os.path.join(os.getcwd(),f"src\\{pack}")
    print(sub_path)
    for j,name in enumerate(os.listdir(sub_path)):   
        im_path = os.path.join(sub_path,name)
        print(im_path)
        os.rename(im_path,f"{target_path}/{i}_{j}.jpg")
# Out:
# C:\Users\asus\Desktop\project\src\2024_TUYZ_Online_Yarisma_Ana_Oturum
# C:\Users\asus\Desktop\project\src\2024_TUYZ_Online_Yarisma_Ana_Oturum\frame_000000.jpg
# C:\Users\asus\Desktop\project\src\2024_TUYZ_Online_Yarisma_Ana_Oturum\frame_000004.jpg
# C:\Users\asus\Desktop\project\src\2024_TUYZ_Online_Yarisma_Ana_Oturum\frame_000008.jpg
# C:\Users\asus\Desktop\project\src\2024_TUYZ_Online_Yarisma_Ana_Oturum\frame_000012.jpg
# C:\Users\asus\Desktop\project\src\2024_TUYZ_Online_Yarisma_Ana_Oturum\frame_000016.jpg
# C:\Users\asus\Desktop\project\src\2024_TUYZ_Online_Yarisma_Ana_Oturum\frame_000020.jpg
# C:\Users\asus\Desktop\project\src\2024_TUYZ_Online_Yarisma_Ana_Oturum\frame_000024.jpg
# C:\Users\asus\Desktop\project\src\2024_TUYZ_Online_Yarisma_Ana_Oturum\frame_000028.jpg
# C:\Users\asus\Desktop\project\src\2024_TUYZ_Online_Yarisma_Ana_Oturum\frame_000032.jpg
# C:\Users\asus\Desktop\project\src\2024_TUYZ_Online_Yarisma_Ana_Oturum\frame_000036.jpg
# ...

# %% [markdown]
# ORIGINAL WIDTH = 1920
# ORIGINIAL HEIGHT = 1080
